# %%
name = "kelechi"
print (name)
# Out:
# kelechi

# %%
x= 10 #X- is our variable and 10 is our value
y= 20 
print (x+y)
# Out:
# 30

# %%
type(x) #this will return the type of the variable x
# Out:
# int

# %%
z = 'chocolate' # this assigns z as chocolate
z= 'Mint chocolate chip '  # this then overide the value of z to mint chocolate chip
print (z)
# Out:
# Mint chocolate chip

# %%
# we can also assign multiple values to multiple variables in one line
x,y,z = "chocolate", "vanilla","strawberry" 
print(x)
print(y)
print(z)
# Out:
# chocolate
# vanilla
# strawberry

# %%
# we can also assign multiple variable to one value
x = y = z = "root bear"
print(x)
print (y)
print (z)
# Out:
# root bear
# root bear
# root bear

# %%
#creating a list variable 
# you can assign list, dictionary, tuple and set to a variable 
# you can create a list variable by using square brackets and separating the values with commas
ice_cream_flavors = ["chocolate", "vanilla", "strawberry"] # the ice_cream_flavours is our variable and the values are the list of ice cream flavors
x, y, z = ice_cream_flavors # this will assign the values of the list( chocolate, vanilla, strawberry) to the variables x, y, and z
print(x)
print(y)
print(z)
# Out:
# chocolate
# vanilla
# strawberry

# %%
#lets consider how you name your variables.

#1 camel case: this is when you start the first word with a lowercase letter and then capitalize the first letter of each subsequent word. For example: myVariableName

# %%
#2 pascal case: this is when you start the first letter of each word with a capital letter. For example: MyVariableName
TestVariableCase = "this is pascal case"

# %%
#3 Snake case: this is when you use underscores to separate words. For example: my_variable_name
test_variable_case = " this is snake case"
#snake case is the most common way to name variables in python. It is also the most readable and easy to understand

# %%
#Some good variballe names you can use are:
testvar = "kelechi"
test_var = "kelechi"
_test_var = "kelechi"
testVar = "kelechi"
TestVar = "kelechi"
testVar2 = "kelechi"

# %%
#some variable names you should avoid using are:
2testvar = "kelechi" # this is not a good variable name because it starts with a number, it wont run
test-var2 = "kelechi" # this is not a good variable name because it has a hyphen, it wont run
test var = "kelechi" # this is not a good variable name because it has a space, it wont run
test,var = "kelechi" # this is not a good variable name because it has a comma, it wont run, or any other special characters like !@#$%^&*()+=-[]{};':"\|,.<>/?~`

# %%
x = "ice cream is my favorite dessert" + 2
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x = "ice cream is my favorite dessert" + 2
#       2 print(x)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = (3 + 2)/5
print(x)
# Out:
# 1.0

# %%
name = "kelechi Ofoegbu"
age = 20
print("my name is " + name + "and i am "+ age + "years old") # this will not run because you cannot concatenate a string and an integer, you need to convert the integer to a string first
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 name = "kelechi Ofoegbu"
#       2 age = 20
# ----> 3 print("my name is " + name + "and i am "+ age + "years old") # this will not run because you cannot concatenate a string and an integer, you need to convert the integer to a string first
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = "kelechi Ofoegbu"
age = 20
print("my name is " + name + " and i am "+ str(age) + " years old") # this will now run because we have converted the integer to a string
# Out:
# my name is kelechi Ofoegbu and i am 20 years old

# %%
name = "kelechi Ofoegbu"
age = 20
print("my name is ", name, " and i am ", age , " years old") # you can combine a string and an integer in a print statement by separating them with commas, this will automatically convert the integer to a string
# Out:
# my name is  kelechi Ofoegbu  and i am  20  years old

# %%
x = "ice cream" 
y = 2
print(x, y)
# Out:
# ice cream 2

# %%
file_path = "encounters.csv"

print(f"File is {file_path}")
# Out:
# File is encounters.csv
